# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\taniy\OneDrive\Desktop\clg\Prodigy\Data Science\a8766791-5e5c-41b9-960b-c5d94daa6e68_Data.csv")   
data
# Out:
#                                           Series Name  Series Code  \
# 0                                   Population, total  SP.POP.TOTL
# 1                                   Population, total  SP.POP.TOTL
# 2                                   Population, total  SP.POP.TOTL
# 3                                   Population, total  SP.POP.TOTL
# 4                                   Population, total  SP.POP.TOTL
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 06/28/2024          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2014 [YR2014]  \
# 0       Afghanistan          AFG      10694796      19542982      32716210
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                           Series Name  Series Code  \
# 0                                   Population, total  SP.POP.TOTL
# 1                                   Population, total  SP.POP.TOTL
# 2                                   Population, total  SP.POP.TOTL
# 3                                   Population, total  SP.POP.TOTL
# 4                                   Population, total  SP.POP.TOTL
# ..                                                ...          ...
# 266                                               NaN          NaN
# 267                                               NaN          NaN
# 268                                               NaN          NaN
# 269  Data from database: World Development Indicators          NaN
# 270                          Last Updated: 06/28/2024          NaN
#
#        Country Name Country Code 1990 [YR1990] 2000 [YR2000] 2014 [YR2014]  \
# 0       Afghanistan          AFG      10694796      19542982      32716210
# ...

# %%
df_cleaned = df.dropna()

# %%
df_cleaned
# Out:
#            Series Name  Series Code  \
# 0    Population, total  SP.POP.TOTL
# 1    Population, total  SP.POP.TOTL
# 2    Population, total  SP.POP.TOTL
# 3    Population, total  SP.POP.TOTL
# 4    Population, total  SP.POP.TOTL
# ..                 ...          ...
# 261  Population, total  SP.POP.TOTL
# 262  Population, total  SP.POP.TOTL
# 263  Population, total  SP.POP.TOTL
# 264  Population, total  SP.POP.TOTL
# 265  Population, total  SP.POP.TOTL
#
#                                    Country Name Country Code 1990 [YR1990]  \
# 0                                   Afghanistan          AFG      10694796
# 1                                       Albania          ALB       3286542
# 2                                       Algeria          DZA      25518074
# 3                                American Samoa          ASM         47818
# 4                                       Andorra          AND         53569
# ...

# %%
df2020=df_cleaned[['Country Code','2023 [YR2023]']]
df2020
# Out:
#     Country Code 2023 [YR2023]
# 0            AFG      42239854
# 1            ALB       2745972
# 2            DZA      45606480
# 3            ASM         43914
# 4            AND         80088
# ..           ...           ...
# 261          SSF    1241897817
# 262          SSA    1241778044
# 263          TSS    1241897817
# 264          UMC    2810588102
# 265          WLD    8024997028
#
# [266 rows x 2 columns]

# %%
df2020new=df2020.sort_values(by='2023 [YR2023]',ascending=False) 
df2020new
# Out:
#     Country Code 2023 [YR2023]
# 211          VNM      98858950
# 95           ISR       9756700
# 87           HUN       9589872
# 204          ARE       9516871
# 6            ATG         94298
# ..           ...           ...
# 44           COD     102262808
# 190          TJK      10143543
# 12           AZE      10112555
# 221          CEB     100156608
# 252          INX            ..
#
# [266 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.hist(df2020['2023 [YR2023]'], bins=30, edgecolor='black')
plt.title('Histogram of NumericColumn')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
df_top10 = df2020new.head(10)
df_top10
# Out:
#     Country Code 2023 [YR2023]
# 211          VNM      98858950
# 95           ISR       9756700
# 87           HUN       9589872
# 204          ARE       9516871
# 6            ATG         94298
# 66           FJI        936375
# 227          ECS     923929755
# 17           BLR       9178298
# 11           AUT       9132383
# 232          HPC     907995430

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df_top10['Country Code'],df_top10['2023 [YR2023]'], color='darkblue')
plt.xlabel('Country Name')
plt.ylabel('Value for 2023')
plt.title('Values for 2023 by Country')
plt.show()

# %%
# plt.bar(df_cleaned ['Country Name'], df_cleaned ['1990 [YR1990]'], color='green')
# plt.xlabel('Country Name')
# plt.ylabel('Value for 1990')
# plt.title('Values for 1990 by Country')
# plt.show()

# %%
# plt.bar(df_cleaned ['Country Name'], df_cleaned ['1990 [YR1990]'], color='darkblue')
# plt.xlabel('Country Name')
# plt.ylabel('Value for 1990')
# plt.title('Values for 1990 by Country')
# plt.show()

# %%
mdata=pd.read_csv(r"C:\Users\taniy\OneDrive\Desktop\clg\Prodigy\Data Science\Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_2430752.csv")
mdata
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
unique_values = mdata['Unnamed: 5'].unique()

# %%
mdata=mdata.drop('Unnamed: 5',axis=1)

# %%
mclean=mdata.dropna()
mclean
# Out:
#     Country Code                      Region          IncomeGroup  \
# 2            AFG                  South Asia           Low income
# 4            AGO          Sub-Saharan Africa  Lower middle income
# 9            ARG   Latin America & Caribbean  Upper middle income
# 14           AUT       Europe & Central Asia          High income
# 16           BDI          Sub-Saharan Africa           Low income
# ..           ...                         ...                  ...
# 259          WSM         East Asia & Pacific  Lower middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName
# 2    The reporting period for national accounts dat...   Afghanistan
# ...

# %%
mclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 2 to 264
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  89 non-null     object
#  1   Region        89 non-null     object
#  2   IncomeGroup   89 non-null     object
#  3   SpecialNotes  89 non-null     object
#  4   TableName     89 non-null     object
# dtypes: object(5)
# memory usage: 4.2+ KB

# %%
region_counts = mclean['Region'].value_counts()
region_counts.plot(kind='bar')
plt.title('Frequency of Regions')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()
